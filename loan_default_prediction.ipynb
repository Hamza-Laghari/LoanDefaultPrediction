# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/Defaul_Loan_Prediction/hmeq.csv')
df
# Out:
#       BAD   LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0       1   1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1       1   1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2       1   1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3       1   1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4       0   1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
# ...   ...    ...      ...       ...      ...     ...   ...    ...     ...
# 5955    0  88900  57264.0   90185.0  DebtCon   Other  16.0    0.0     0.0
# 5956    0  89000  54576.0   92937.0  DebtCon   Other  16.0    0.0     0.0
# 5957    0  89200  54045.0   92924.0  DebtCon   Other  15.0    0.0     0.0
# 5958    0  89800  50370.0   91861.0  DebtCon   Other  14.0    0.0     0.0
# 5959    0  89900  48811.0   88934.0  DebtCon   Other  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# 0      94.366667   1.0   9.0        NaN
# 1     121.833333   0.0  14.0        NaN
# 2     149.466667   1.0  10.0        NaN
# 3            NaN   NaN   NaN        NaN
# 4      93.333333   0.0  14.0        NaN
# ...          ...   ...   ...        ...
# 5955  221.808718   0.0  16.0  36.112347
# 5956  208.692070   0.0  15.0  35.859971
# 5957  212.279697   0.0  15.0  35.556590
# 5958  213.892709   0.0  16.0  34.340882
# 5959  219.601002   0.0  16.0  34.571519
#
# [5960 rows x 13 columns]

# %%
df.shape
# Out:
# (5960, 13)

# %%
df.describe()
# Out:
#                BAD          LOAN        MORTDUE          VALUE          YOJ  \
# count  5960.000000   5960.000000    5442.000000    5848.000000  5445.000000
# mean      0.199497  18607.969799   73760.817200  101776.048741     8.922268
# std       0.399656  11207.480417   44457.609458   57385.775334     7.573982
# min       0.000000   1100.000000    2063.000000    8000.000000     0.000000
# 25%       0.000000  11100.000000   46276.000000   66075.500000     3.000000
# 50%       0.000000  16300.000000   65019.000000   89235.500000     7.000000
# 75%       0.000000  23300.000000   91488.000000  119824.250000    13.000000
# max       1.000000  89900.000000  399550.000000  855909.000000    41.000000
#
#              DEROG       DELINQ        CLAGE         NINQ         CLNO  \
# count  5252.000000  5380.000000  5652.000000  5450.000000  5738.000000
# mean      0.254570     0.449442   179.766275     1.186055    21.296096
# std       0.846047     1.127266    85.810092     1.728675    10.138933
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000   115.116702     0.000000    15.000000
# 50%       0.000000     0.000000   173.466667     1.000000    20.000000
# 75%       0.000000     0.000000   231.562278     2.000000    26.000000
# max      10.000000    15.000000  1168.233561    17.000000    71.000000
#
#            DEBTINC
# count  4693.000000
# mean     33.779915
# std       8.601746
# min       0.524499
# 25%      29.140031
# 50%      34.818262
# 75%      39.003141
# max     203.312149

# %%
df.values
# Out:
# array([[1, 1100, 25860.0, ..., 1.0, 9.0, nan],
#        [1, 1300, 70053.0, ..., 0.0, 14.0, nan],
#        [1, 1500, 13500.0, ..., 1.0, 10.0, nan],
#        ...,
#        [0, 89200, 54045.0, ..., 0.0, 15.0, 35.55659049],
#        [0, 89800, 50370.0, ..., 0.0, 16.0, 34.340882368],
#        [0, 89900, 48811.0, ..., 0.0, 16.0, 34.571519125]], dtype=object)

# %%
df.isnull().any()
# Out:
# BAD        False
# LOAN       False
# MORTDUE     True
# VALUE       True
# REASON      True
# JOB         True
# YOJ         True
# DEROG       True
# DELINQ      True
# CLAGE       True
# NINQ        True
# CLNO        True
# DEBTINC     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# BAD           0
# LOAN          0
# MORTDUE     518
# VALUE       112
# REASON      252
# JOB         279
# YOJ         515
# DEROG       708
# DELINQ      580
# CLAGE       308
# NINQ        510
# CLNO        222
# DEBTINC    1267
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# BAD         0.000000
# LOAN        0.000000
# MORTDUE     8.691275
# VALUE       1.879195
# REASON      4.228188
# JOB         4.681208
# YOJ         8.640940
# DEROG      11.879195
# DELINQ      9.731544
# CLAGE       5.167785
# NINQ        8.557047
# CLNO        3.724832
# DEBTINC    21.258389
# dtype: float64

# %%
df.info
# Out:
# <bound method DataFrame.info of       BAD   LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0       1   1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1       1   1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2       1   1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3       1   1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4       0   1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
# ...   ...    ...      ...       ...      ...     ...   ...    ...     ...
# 5955    0  88900  57264.0   90185.0  DebtCon   Other  16.0    0.0     0.0
# 5956    0  89000  54576.0   92937.0  DebtCon   Other  16.0    0.0     0.0
# 5957    0  89200  54045.0   92924.0  DebtCon   Other  15.0    0.0     0.0
# 5958    0  89800  50370.0   91861.0  DebtCon   Other  14.0    0.0     0.0
# 5959    0  89900  48811.0   88934.0  DebtCon   Other  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# 0      94.366667   1.0   9.0        NaN
# 1     121.833333   0.0  14.0        NaN
# 2     149.466667   1.0  10.0        NaN
# 3            NaN   NaN   NaN        NaN
# 4      93.333333   0.0  14.0        NaN
# ...          ...   ...   ...        ...
# 5955  221.808718   0.0  16.0  36.112347
# 5956  208.692070   0.0  15.0  35.859971
# 5957  212.279697   0.0  15.0  35.556590
# 5958  213.892709   0.0  16.0  34.340882
# 5959  219.601002   0.0  16.0  34.571519
#
# [5960 rows x 13 columns]>

# %%
df["DEBTINC_missing"] = df["DEBTINC"].isnull().astype(int)
df["DEBTINC"] = df["DEBTINC"].fillna(df["DEBTINC"].median())

# %%
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.show()

# %%
df.dtypes
# Out:
# BAD          int64
# LOAN         int64
# MORTDUE    float64
# VALUE      float64
# REASON      object
# JOB         object
# YOJ        float64
# DEROG      float64
# DELINQ     float64
# CLAGE      float64
# NINQ       float64
# CLNO       float64
# DEBTINC    float64
# dtype: object

# %%
df["REASON'value_counts(dropna=False)
df["REASON"].nunique()
# Out:
# 6

# %%
df["JOB"] = df["JOB"].fillna("Unknown")

# %%
df = pd.get_dummies(df, columns=["JOB"], drop_first=True)

# %%
df['BAD'].value_counts(normalize=True)
# Out:
# BAD
# 0    0.800503
# 1    0.199497
# Name: proportion, dtype: float64

# %%
df["REASON"].value_counts(dropna=False)
df["REASON"].nunique()
# Out:
# 2

# %%
numeric_features = df.select_dtypes(include=['int64', 'float64']).columns
print(numeric_features)
# Out:
# Index(['BAD', 'LOAN', 'MORTDUE', 'VALUE', 'YOJ', 'DEROG', 'DELINQ', 'CLAGE',
#        'NINQ', 'CLNO', 'DEBTINC'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
print(df[numeric_features].head())
# Out:
#         BAD      LOAN   MORTDUE     VALUE       YOJ     DEROG    DELINQ  \
# 0  2.003151 -1.562299 -1.077548 -1.093588  0.208329 -0.300922 -0.398738
# 1  2.003151 -1.544453 -0.083409 -0.581658 -0.253822 -0.300922  1.375631
# 2  2.003151 -1.526606 -1.355591 -1.482655 -0.649951 -0.300922 -0.398738
# 3  2.003151 -1.526606       NaN       NaN       NaN       NaN       NaN
# 4 -0.499213 -1.508759  0.540771  0.178177 -0.781994 -0.300922 -0.398738
#
#       CLAGE      NINQ      CLNO  DEBTINC
# 0 -0.995304 -0.107639 -1.212866      NaN
# 1 -0.675189 -0.686169 -0.719675      NaN
# 2 -0.353132 -0.107639 -1.114228      NaN
# 3       NaN       NaN       NaN      NaN
# 4 -1.007348 -0.686169 -0.719675      NaN

# %%
X = df.drop('BAD', axis=1)   # Features (all columns except BAD)
y = df['BAD']                # Target (BAD column)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,   # keeps class distribution same in train/test
    random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

numeric_features = X_train.select_dtypes(include=['int64','float64']).columns

scaler = StandardScaler()
X_train[numeric_features] = scaler.fit_transform(X_train[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# %%
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
print(X_train.dtypes)
# Out:
# LOAN           float64
# MORTDUE        float64
# VALUE          float64
# REASON          object
# YOJ            float64
# DEROG          float64
# DELINQ         float64
# CLAGE          float64
# NINQ           float64
# CLNO           float64
# DEBTINC        float64
# JOB_Office        bool
# JOB_Other         bool
# JOB_ProfExe       bool
# JOB_Sales         bool
# JOB_Self          bool
# JOB_Unknown       bool
# dtype: object

# %%
# One-hot encode the REASON column
df = pd.get_dummies(df, columns=['REASON'], drop_first=True)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
print(y_train.unique())
print(y_train.dtype)
# Out:
# [-0.49921338  2.00315143]
# float64

# %%
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
print(y.unique())
print(y.dtype)
# Out:
# [ 2.00315143 -0.49921338]
# float64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")  # you can use "median" if skewed data
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R² Score:", r2)
# Out:
# MSE: 0.8025846740654902
# R² Score: 0.19792165148422147

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

print("Random Forest MSE:", mean_squared_error(y_test, y_pred_rf))
print("Random Forest R²:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest MSE: 0.4602402763119413
# Random Forest R²: 0.5400500748727165

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

rf = RandomForestRegressor(random_state=42)

# Parameter grid
param_dist = {
    "n_estimators": [100, 200, 300, 500],
    "max_depth": [None, 10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2", None]
}

# Randomized Search
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=30,  # number of combinations to try
    cv=5,       # 5-fold cross validation
    scoring="r2", # optimizing R²
    verbose=2,
    random_state=42,
    n_jobs=-1
)

random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
print("Best CV R² Score:", random_search.best_score_)

# Train final model with best params
best_rf = random_search.best_estimator_
y_pred_best = best_rf.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
print("Test MSE:", mean_squared_error(y_test, y_pred_best))
print("Test R²:", r2_score(y_test, y_pred_best))
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
